# %% [markdown]
# PROYECTO CAMPAÑA DE MARKETING BANCARIO

# %%
import pandas as pd 

data= pd.read_csv("https://storage.googleapis.com/breathecode/project-files/bank-marketing-campaign-data.csv", sep=';')

print(data.shape)
data.head()
# Out:
# (41188, 21)
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
data.drop(["day_of_week","cons.conf.idx","euribor3m","nr.employed","cons.price.idx","emp.var.rate"], axis = 1, inplace = True)
data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month  duration  campaign  pdays  previous     poutcome   y
# 0   may       261         1    999         0  nonexistent  no
# 1   may       149         1    999         0  nonexistent  no
# 2   may       226         1    999         0  nonexistent  no
# 3   may       151         1    999         0  nonexistent  no
# 4   may       307         1    999         0  nonexistent  no

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        41188 non-null  int64
#  1   job        41188 non-null  object
#  2   marital    41188 non-null  object
#  3   education  41188 non-null  object
#  4   default    41188 non-null  object
#  5   housing    41188 non-null  object
#  6   loan       41188 non-null  object
#  7   contact    41188 non-null  object
#  8   month      41188 non-null  object
#  9   duration   41188 non-null  int64
#  10  campaign   41188 non-null  int64
#  11  pdays      41188 non-null  int64
#  12  previous   41188 non-null  int64
#  13  poutcome   41188 non-null  object
#  14  y          41188 non-null  object
# dtypes: int64(5), object(10)
# memory usage: 4.7+ MB

# %% [markdown]
# ANALISIS UNIVARIABLE

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#CATEGORICAS
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.countplot(x='education', data = data, palette= "Set2")
plt.xlabel("Educación")
plt.ylabel("Cantidad")
plt.xticks(rotation=90)



plt.subplot(2,2,2)
sns.countplot(x='default', data = data, palette= "Set2")
plt.xlabel("¿Tiene credito?")


plt.subplot(2,2,3)
sns.countplot(x='job', data = data, palette= "Set2")
plt.xlabel("Trabajo")
plt.ylabel("Cantidad")
plt.xticks(rotation=90)

plt.subplot(2,2,4)
sns.countplot(x='poutcome', data = data, palette= "Set2")
plt.xlabel("Resultado campaña anterior")
plt.show()
# Out:
# /tmp/ipykernel_775/3991273854.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='education', data = data, palette= "Set2")
# /tmp/ipykernel_775/3991273854.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='default', data = data, palette= "Set2")
# /tmp/ipykernel_775/3991273854.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='job', data = data, palette= "Set2")
# /tmp/ipykernel_775/3991273854.py:25: FutureWarning:
#
# ...

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.countplot(x='marital', data = data, palette= "Set2")
plt.xlabel("estado civil")
plt.ylabel("Cantidad")
plt.xticks(rotation=90)
# Out:
# /tmp/ipykernel_775/1671439071.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='marital', data = data, palette= "Set2")
# ([0, 1, 2, 3],
#  [Text(0, 0, 'married'),
#   Text(1, 0, 'single'),
#   Text(2, 0, 'divorced'),
#   Text(3, 0, 'unknown')])

# %%
#NUMERICAS

plt.figure(figsize=(20,20))
plt.subplot(2,2,1)
sns.distplot(data['age']);
plt.xlabel("Edad")
plt.ylabel("Clientes")


plt.subplot(2,2,2)
sns.distplot(data['duration']);
plt.xlabel("Duracion llamada en segundos")
plt.ylabel("Clientes")

plt.subplot(2,2,3)
sns.distplot(data['campaign']);
plt.xlabel("Número de contactos realizados")
plt.ylabel("Clientes")

plt.subplot(2,2,4)
sns.distplot(data['previous']);
plt.xlabel("Número de contactos realizados campaña anterior")
plt.ylabel("Clientes")

plt.show()
# Out:
# /tmp/ipykernel_775/1554686648.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['age']);
# /tmp/ipykernel_775/1554686648.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['duration']);
# /tmp/ipykernel_775/1554686648.py:16: UserWarning:
#
# ...

# %% [markdown]
# ANALISIS MULTIVARIADO

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.countplot(x='education', hue="y", data = data, palette= "Set1")
plt.xlabel("Educación")
plt.ylabel("Cantidad")
plt.xticks(rotation=90)

plt.subplot(2,2,2)
sns.countplot(x='default',hue="y", data = data, palette= "Set1")
plt.xlabel("¿Tiene credito?")


plt.subplot(2,2,3)
sns.countplot(x='job', hue="y", data = data, palette= "Set1")
plt.xlabel("Trabajo")
plt.ylabel("Cantidad")
plt.xticks(rotation=90)

plt.subplot(2,2,4)
sns.countplot(x='poutcome',hue="y", data = data, palette= "Set1")
plt.xlabel("Resultado campaña anterior")
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.countplot(x='marital', hue="y", data = data, palette= "Set1")
plt.xlabel("Estado civil")
plt.ylabel("Cantidad")
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'married'),
#   Text(1, 0, 'single'),
#   Text(2, 0, 'divorced'),
#   Text(3, 0, 'unknown')])

# %% [markdown]
# CORRELACION

# %%
fig, axis = plt.subplots(2, 2, figsize = (10, 16))
sns.regplot(ax = axis[0,0], data = data, x = "duration", y = "age")
sns.heatmap(data[["duration", "age"]].corr(), annot = True, fmt = ".2f", ax = axis[1,0], cbar = False)

sns.regplot(ax = axis[0,1], data =data, x = "campaign", y = "age").set(ylabel = None)
sns.heatmap(data[["campaign", "age"]].corr(), annot = True, fmt = ".2f", ax = axis[1,1])
# Out:
# <Axes: >

# %%
fig, axis = plt.subplots(2, 2, figsize = (15, 10))

sns.boxplot(ax = axis[0, 0], data = data, y = "campaign")
sns.boxplot(ax = axis[0, 1], data = data, y = "duration")
sns.boxplot(ax = axis[1, 0], data = data, y = "previous")
sns.boxplot(ax = axis[1, 1], data = data, y = "poutcome")


plt.tight_layout()

plt.show()

# %%
duration_stats =data['duration'].describe()
duration_stats
# Out:
# count    41188.000000
# mean       258.285010
# std        259.279249
# min          0.000000
# 25%        102.000000
# 50%        180.000000
# 75%        319.000000
# max       4918.000000
# Name: duration, dtype: float64

# %%
duration_iqr = duration_stats["75%"]-duration_stats["25%"]
upper_limit= duration_stats["75%"] + 1.5 * duration_iqr
lower_limit= duration_stats["25%"] - 1.5 * duration_iqr

print(duration_iqr, upper_limit, lower_limit)
# Out:
# 217.0 644.5 -223.5

# %%
data[data["duration"]> 4000]
# Out:
#        age          job  marital            education default housing loan  \
# 22192   52  blue-collar  married             basic.4y      no      no   no
# 24091   33   technician   single  professional.course      no     yes   no
#
#          contact month  duration  campaign  pdays  previous     poutcome    y
# 22192  telephone   aug      4199         3    999         0  nonexistent  yes
# 24091  telephone   nov      4918         1    999         0  nonexistent   no

# %%
campaign_stats =data['campaign'].describe()
campaign_stats
# Out:
# count    41188.000000
# mean         2.567593
# std          2.770014
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         56.000000
# Name: campaign, dtype: float64

# %%
campaign_iqr = campaign_stats["75%"]-campaign_stats["25%"]
upper_limit= campaign_stats["75%"] + 1.5 * campaign_iqr
lower_limit= campaign_stats["25%"] - 1.5 * campaign_iqr

print(campaign_iqr, upper_limit, lower_limit)
# Out:
# 2.0 6.0 -2.0

# %%
# eliminar valores atipico
data=data[data["campaign"]< 40]
data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month  duration  campaign  pdays  previous     poutcome   y
# 0   may       261         1    999         0  nonexistent  no
# 1   may       149         1    999         0  nonexistent  no
# 2   may       226         1    999         0  nonexistent  no
# 3   may       151         1    999         0  nonexistent  no
# 4   may       307         1    999         0  nonexistent  no

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41180 entries, 0 to 41187
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        41180 non-null  int64
#  1   job        41180 non-null  object
#  2   marital    41180 non-null  object
#  3   education  41180 non-null  object
#  4   default    41180 non-null  object
#  5   housing    41180 non-null  object
#  6   loan       41180 non-null  object
#  7   contact    41180 non-null  object
#  8   month      41180 non-null  object
#  9   duration   41180 non-null  int64
#  10  campaign   41180 non-null  int64
#  11  pdays      41180 non-null  int64
#  12  previous   41180 non-null  int64
#  13  poutcome   41180 non-null  object
#  14  y          41180 non-null  object
# dtypes: int64(5), object(10)
# memory usage: 5.0+ MB

# %% [markdown]
# FUNCION TRAMPITA

# %%
def scaler(X_train_, X_test_, nums):
  X_train = X_train_.copy()
  X_test = X_test_.copy()
  scaler = StandardScaler()
  # Train
  X_train_scaled = pd.DataFrame(
             scaler.fit_transform(X_train[nums]),
             columns=scaler.get_feature_names_out(),
             index = X_train.index)
  X_train_scaled = X_train_scaled.join(X_train[list(set(X_train.columns)  - set(nums))])
  # Test
  X_test_scaled = pd.DataFrame(
      scaler.transform(X_test[nums]),
      columns = scaler.get_feature_names_out(),
      index = X_test.index)
  X_test_scaled = X_test_scaled.join(X_test[list(set(X_test.columns)  - set(nums))])
  X_test_scaled = X_test_scaled[X_train_scaled.columns]
  return X_train_scaled, X_test_scaled


def to_binary(X_train_, X_test_, cats):
  X_train =  X_train_.copy()
  X_test = X_test_.copy()
  ohe = OneHotEncoder(handle_unknown='ignore', drop='first')
  # train
  X_train_bin = pd.DataFrame(ohe.fit_transform(
      X_train[cats]).toarray(),
      columns = ohe.get_feature_names_out(),
      index = X_train.index)
  X_train_bin = X_train_bin.join(X_train[list(set(X_train.columns)  - set(cats))])
  # test
  X_test_bin = pd.DataFrame(ohe.transform(X_test[cats]).toarray(),
      columns = ohe.get_feature_names_out(),
      index = X_test.index)
  X_test_bin = X_test_bin.join(X_test[list(set(X_test.columns)  - set(cats))])
  X_test_bin = X_test_bin[X_train_bin.columns]
  return X_train_bin, X_test_bin

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report

# %%
numericals = ['age','duration','campaign','pdays','previous']
categorical = ["job", "education", "contact", "month","marital","default", "housing","loan", "poutcome"]
y  = 'y'

# %%
data = data[numericals + categorical + [y]]

# %%
X, y = data.drop(columns='y'), data[y]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
X_train_ml , X_test_ml = scaler(X_train, X_test, numericals)

# %%
X_train_ml, X_test_ml = to_binary(X_train_ml, X_test_ml, categorical)

# %%
model = LogisticRegression()
model.fit(X_train_ml, y_train)
# Out:
# LogisticRegression()

# %%
preds = model.predict(X_test_ml)
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.92      0.98      0.95      7312
#          yes       0.67      0.34      0.46       924
#
#     accuracy                           0.91      8236
#    macro avg       0.80      0.66      0.70      8236
# weighted avg       0.89      0.91      0.89      8236

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, preds)
# Out:
# 0.9076007770762506

# %% [markdown]
# OPTIMIZACION

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import Ridge, Lasso

# %%
hyperparams = {
    "C": [0.001, 0.01, 0.1, 1, 10, 100, 1000],
    "penalty": ["l1", "l2", "elasticnet", None],
    "solver": ["newton-cg", "lbfgs", "liblinear", "sag", "saga"]
}

grid = RandomizedSearchCV(model, hyperparams, scoring = "accuracy", cv = 5)

grid.fit(X_train_ml, y_train)
print(f"Best hyperparameters: {grid.best_params_}")
# Out:
# Best hyperparameters: {'solver': 'saga', 'penalty': 'l1', 'C': 1000}

# %%
model = LogisticRegression(solver= 'saga', penalty= 'l1', C= 1000)
model.fit(X_train_ml, y_train)
# Out:
# LogisticRegression(C=1000, penalty='l1', solver='saga')

# %%
preds = model.predict(X_test_ml)
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.92      0.98      0.95      7312
#          yes       0.67      0.34      0.46       924
#
#     accuracy                           0.91      8236
#    macro avg       0.80      0.66      0.70      8236
# weighted avg       0.89      0.91      0.89      8236

# %%
accuracy_score(y_test, preds)
# Out:
# 0.907722195240408

# %% [markdown]
# Ya está re bueno el modelo, no se puede optimizar mucho más
